# %% [markdown]
# 1.  Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %% [markdown]
# 2. Loading

# %%
data = fetch_20newsgroups(subset='all')
articles = data.data
print("Total articles:", len(articles))
# Out:
# Total articles: 18846

# %% [markdown]
# 3. Conversion of text to numbers

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.5)
X = vectorizer.fit_transform(articles)

# %% [markdown]
# 4. Apply K-means clustering

# %%
k = 5
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_

# %% [markdown]
# 5. Print sample articles

# %%
for i in range(k):
    print(f"\nCluster {i}:")
    for j in np.where(labels == i)[0][:3]:
        print("-", articles[j][:100])
# Out:
# Cluster 0:
# - From: Mamatha Devineni Ratnam <mr47+@andrew.cmu.edu>
# Subject: Pens fans reactions
# Organization: Post
# - From: lpa8921@tamuts.tamu.edu (Louis Paul Adams)
# Subject: Re: Number for Applied Engineering
# Organiz
# - From: dchhabra@stpl.ists.ca (Deepak Chhabra)
# Subject: Re: Atlanta Hockey Hell!!
# Nntp-Posting-Host: s
#
# Cluster 1:
# - From: hilmi-er@dsv.su.se (Hilmi Eren)
# Subject: Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES (
# - From: arromdee@jyusenkyou.cs.jhu.edu (Ken Arromdee)
# Subject: Re: Christians above the Law? was Clari
# - From: sandvik@newton.apple.com (Kent Sandvik)
# Subject: Re: 14 Apr 93   God's Promise in 1 John 1: 7
#
#
# Cluster 2:
# - From: tell@cs.unc.edu (Stephen Tell)
# Subject: Re: subliminal message flashing on TV
# Organization: Th
# - From: steve-b@access.digex.com (Steve Brinich)
# Subject: Re: Fighting the Clipper Initiative
# Organiza
# - From: jackw@boi.hp.com (jack wood)
# Subject: Re: Chevy/GMC 4x4 Fullsize Pickups, Opinions?
# Distributi
#
# Cluster 3:
# - From: mblawson@midway.ecn.uoknor.edu (Matthew B Lawson)
# Subject: Which high-performance VLB video ca
# - From: guyd@austin.ibm.com (Guy Dawson)
# Subject: Re: IDE vs SCSI, DMA and detach
# Originator: guyd@pal
# - From: Alexander Samuel McDiarmid <am2o+@andrew.cmu.edu>
# Subject: driver ??
# Organization: Sophomore,
#
# Cluster 4:
# - From: csulo@csv.warwick.ac.uk (Mr M J Brown)
# Subject: 600RPM Floopy drives - UPDATE!
# Organization: C
# - From: mjs@sys.uea.ac.uk (Mike Sixsmith)
# Subject: Re: Countersteering_FAQ please post
# Organization: U
# - From: cws@Faultline.Com (Carl Schmidtmann)
# Subject: Re: Any way to *STOP* and application from re-ti

# %% [markdown]
# Another method:
# To determine the optimal number of clusters (k) for the dataset

# %%
i = []
K = range(1, 10)
for k in K:
    model = KMeans(n_clusters=k, random_state=42)
    model.fit(X)
    i.append(model.inertia_)

plt.plot(K, i)
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
